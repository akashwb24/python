# %%
def message():
    x = 10
    print(x)

# %%
message()

# %%
a = 20
def message2():
    print(a)

# %%
message2()

# %%
def message3():
    global b#if making a variable inside the function and we want to access it from outisde, then we will write separately "global b" or any other variable
    b = 30
    print(b)

# %%
message3()#again we cannot directly call any global variable outside the scope of the function, 
#we would first need to call the function then we can access the global variable

# %%
print(b)
