# %%
import functools

# %%
help(functools.reduce)

# %%
lst = [1,2,3,4,5]
print(lst)

# %%
sum(lst)

# %%
def add(x,y):
    print(x,y)#print statement is added here to see how the function is called in functools.reduce
    return x+y

# %%
functools.reduce(add, lst)

# %%
functools.reduce(lambda x,y : x+y, lst)
