# %%
lst = [10,20,40,30,60,50]
print (lst)

# %%
lst[0] = 80
print (lst)

# %%
#mutable = can be changed, updated that is changeable
#immutable = cannot be changed, updated that is unchangeable
#mutable = list, dict, set
#immutable = int, float, string, bool, tuple
