# %%
# %pip install monthdelta

# %%
import monthdelta
import datetime

# %%
help(monthdelta)

# %%
monthdelta.monthdelta()

# %%
d1 = datetime.datetime(2022,1,12)

# %%
d1 + monthdelta.monthdelta(8)

# %%
d1 + monthdelta.monthdelta(12)#yeardelta is not available, no such thing exists, we should enter year month wise in multiples of 12

# %%
d1 = datetime.date(2021,1,12)
d2 = datetime.date(2023,10,22)
monthdelta.monthmod(d1,d2)#returns tuple,

# %%
# %pip uninstall -y monthdelta
