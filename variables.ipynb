# %%
x = 100
print(x)

y = "hello"
print(y)

z = 120.30
print(z)

# %%
type(z)

# %%
a = 100
b = 100
print (a, b)

# %%
a = b = 500
print (a)

# %%
a = 10
b = 20
print (a, b)

# %%
a,b = b,a
print(a, b)

# %%
a,b = 100, 200
print(a, b)
