# %%
def addnum(x,y): #inside the function we can define the function literally as how this function works, to do this we have to use triple double quotes like """ message here"""
  """
  this function adds 2 numbers and returns its sum
  """
  return x+y

# %%
addnum(5,8)

# %%
help(addnum)

# %%
addnum.__doc__   #to access the doc string we can also append this " __doc__" to the end of said function using .(dot)
