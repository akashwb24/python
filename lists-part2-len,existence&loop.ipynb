# %%
lst = [10,20,30,40,50,"hi"]
print(lst)
len(lst)

# %%
20 in lst

# %%
100 in lst

# %%
"hi" in lst

# %%
if 20 in lst:
    print("found")
else:
    print("doesnt exist")

# %%
for i in lst:
    print(i)
