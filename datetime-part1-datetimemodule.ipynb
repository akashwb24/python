# %%
dir()

# %%
import datetime

# %%
dir()

# %%
help(datetime.datetime)

# %%
datetime.datetime.now()

# %%
currentDatetime = datetime.datetime.now()
print(currentDatetime)

# %%
datetime.datetime.today()

# %%
yr = currentDatetime.year #returns integer
print(yr)

# %%
mn = currentDatetime.month #returns integer
print(mn)

# %%
dy = currentDatetime.day #returns integer
print(dy)

# %%
datetime.datetime(2023,11,25)

# %%
dt = datetime.date(2022,11,25)
print(dt)

# %%
dtt = datetime.time(11,55,50)
print(dtt)
