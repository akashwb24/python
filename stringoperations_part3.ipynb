# %%
x = "hello"
print(x)
x.replace("l","x")#replaces all occurences of the given character in the given string, is case sensitive
x.replace("E","m")#is case sensitive, if character not found then returns the same string as output, so beware

# %%
x.replace("l","xoxo")

# %%
x.replace("el","x")

# %%
x.replace("e","")#removes the occurence of the character

# %%
x.replace("e"," ")

# %%
x.replace("l","x",1)#replace the first occurence of 'l' in the string as said in the argument as 1

# %%
x.replace("l","x",2)#replaces both the occurences of l by x

# %%
x.count("l")

# %%
x.startswith("h")#case sensitive

# %%
x.endswith("lo")

# %%
y = "i love python"
y.split(" ")

# %%
lst = y.split(" ")
print(lst)

# %%
for i in lst:
  print(i)

# %%
x[0]

# %%
#x[0] = "H"#error, we cant replace any character individually in a string
w="hi"
w="hihi"
print(w)
