# %%
x = 'hello world'
print(x)
x.upper()
y = 'HELLO'
y.lower()

# %%
x.capitalize()

# %%
m = 'Hello'
m.swapcase()

# %%
k = 'myname'
k.islower()

# %%
l = 'RANIKHET'
l.isupper()

# %%
a = "hello"
print(a)
a.find("e")#return index, case sensitive

# %%
d = 'heheli'
d.find("e") # firstly we have to find the first occurence of e
d.find("e",d.find("e")+1) # then we have to find the second occurence of e

# %%
d.index("e")

# %%
g = 'i love "python"'
print(g)

h = "i love \"myself\""
print(h)
