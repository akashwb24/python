# %%
import random

# %%
random.random()#provides a value between 0 and 1, cant be changed, everytime we run this new values would be generated

# %%
random.randint(1,100)#paramerters are start and end, it will give a random value between them

# %%
random.random() * 100
