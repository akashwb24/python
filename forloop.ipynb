# %%
print(1)
print(2)
print(3)

# %%
range(10)

# %%
range(1,10)

# %%
for i in range(10):
    print(i)

# %%
for i in range(1,11):
    print(i)

# %%
for i in range(0,11,2):
    print(i)

# %%
for i in range(10,0,-1):
    print(i)

# %%
for i in range (1,10,2):
    print(i)
    print("hello")

# %%
for i in range (1,11):
    print(i)
print("loop exited")
