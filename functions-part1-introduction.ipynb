# %%
def printmessage():
    print("Hello World")

# %%
printmessage()

# %%
def printmessage2(empname):
    print(f"hello {empname}")

# %%
printmessage2("sam")

# %%
printmessage2("akash")

# %%
def addnumbers(x,y):
    print(x+y)

# %%
addnumbers(3,5)

# %%
def addnumbers2(x,y):
    return x+y

# %%
a = addnumbers2(5,7)
print(a)

# %%
type(addnumbers2)
