# %%
a = int(input("enter a number"))
if a > 90:
    print("high")
else:
    print("low")

# %%
a = int(input("enter a number"))
if a > 90:
    print("high")
elif a > 75:
    print ("avg")
elif a > 60:
    print("medium")
else:
    print("low")
#sequence is compulsory for comparing numbers
