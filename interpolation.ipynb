# %%
x = 100
print (x)

# %%
print("x")

# %%
print("the value of variable x is : ", x)

# %%
print ("the value of variable x is : " + str(x))

# %%
y = "hello"
print ("the value of y is : " + y)

# %%
print ("the value of variable x is " + str(x) + " and value of variable y is : " + y)

# %%
print("the value of x is : %s" %(x))

# %%
print("the value of x is %s "%(x) + "and the value of y is %s"%(y))

# %%
print("the value of x is %s and the value of y is %s " %(x,y))

# %%
print("the value of x is {}".format(x))

# %%
print("the value of x is {} and the value of y is {}".format(x,y))

# %%
print("the value of x is {a1} and the value of y is {b1}".format(a1=x,b1=y))
#naming here is optional but can be very useful as we dont need to pass the variables in their respective sequence

# %%
print(f"the value of x is {x} and the value of y is {y}")

# %%
a = 100.256984
type(a)
print(f"the value of a is {a}")
print(f"the value of a is %.2f"%(a))
print(f"the value of a is %.3f"%(a))
print(f"the value of a is %.4f"%(a))
