# %%
import datetime

# %%
d1 = datetime.datetime(2023,3,15)
d2 = datetime.datetime(2023,6,25)

# %%
d2-d1

# %%
d1 + datetime.timedelta(10)

# %%
d1 + datetime.timedelta(-45)

# %%
d1 +datetime.timedelta(hours=12)

# %%
d1 +datetime.timedelta(days=4,hours=12)

# %%
d1.timestamp()#it gives the time in seconds from when UTC started to the current time

# %%
dt = datetime.datetime(1970,1,1)
dt.timestamp()

# %%
datetime.datetime.fromtimestamp(1678838400.0
)
