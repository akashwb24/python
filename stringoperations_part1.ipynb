# %%
x = 'hello world'
print(x)
len(x)

# %%
x[0]
x[2]
x[0:5]

# %%
"e" in x #true
"E" in x #false
#case sensitive

# %%
if "e" in x:
    print("character exists")
else:
    print("character doesnt exist")

# %%
for i in x:
    print(i)

# %%
for i in enumerate(x):
    print(i)
#enumerate takes the argument as the string variable, and gives the index along with its value, provides tuple

# %%
list(enumerate(x))

# %%
y= "             hi                          my                    world                       "
print(y)
y.strip()#removes space from the leading/start and trailing/end of the string, not from the middle of the string

# %%
y.lstrip()

# %%
y.rstrip()

# %%
z = "************   hello       ************       world            ******************"
print(z)
z.strip()
print(z.strip("*"))
print(z)
