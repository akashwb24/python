# %%
def doublenum(x):
     return x*2

# %%
doublenum(4)

# %%
lambda x : x * 2
# This is an anonymous function, it doesnt have any name, multiple arguments can be given separated by comma(,)

# %%
#using lambda functions via assigning it to a variable and passing a parameter to it, as its a function
y = lambda x : x * 2
y(4)

# %%
type(y)

# %%
def add(x,y):
    return x+y

# %%
add(50,90)

# %%
a = lambda x,y :x+y

# %%
print(a(10,80))
