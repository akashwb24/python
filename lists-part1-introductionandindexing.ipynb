# %%
[12,23,34,45,56,67,78,89,90]

# %%
mynums = [12,23,34,45,56,67,78,89,90]
print(mynums)
type(mynums)

# %%
countries = ["india","USA","UK","Canada"]
print(countries)
type(countries)

# %%
listmixed = [1,"a",23,56.7,"hello"]
print(listmixed)

# %%
print(mynums)

# %%
print(mynums[3])
mynums[1]

# %%
mynums[-1]#first from last
mynums[-2]#second from last

# %%
mynums[0:5] #first to fifth element

# %%
print(mynums)
mynums[0:10:2] #from first to last with jumping 2 steps

# %%
mynums[2:] #from second to last element

# %%
mynums[:3] #start to third element

# %%
mynums[0:3] #start to third element

# %%
mynums[-3:]#from last to third last
