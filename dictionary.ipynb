# %%
mydt = {"id":1,"name":"akash","salary":10000}
print(mydt)

print(mydt["id"])
print(mydt["name"])
print(mydt["salary"])

type(mydt)

# %%
mydt['salary'] = 20000
print(mydt)

# %%
mydt['name'] = 'AKP'
print(mydt)

# %%
mydt['id']= 2
print(mydt)

# %%
print(mydt['name'])

# %%
mydt["city"] = "Delhi"

# %%
print(mydt)

# %%
for i in mydt:
    print(i)

# %%
for i in mydt.values():
    print(i)

# %%
for i,j in mydt.items():
    print(i,j)
