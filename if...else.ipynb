# %%
x=10
y=20
z=10

# %%
x==y
x==z
x==z

# %%
if x ==z:
    print("both values are same")

# %%
if x==y:
    print("both values are same")
else:
    print("both values are not same")

# %%
if x ==z and x==y:
    print("yes")
else:
    print("no")

# %%
if x==z or x==y:
    print("yes")
else:
    print("no")
